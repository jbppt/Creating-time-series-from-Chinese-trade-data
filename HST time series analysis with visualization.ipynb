# %%
import pandas as pd

# %%
#loading a local excel sheet into pandas and then showing the first 15 rows of monthly trade data. creating a dataframe for that sheet.
df = pd.read_excel('itc_textile_apparel_import_monitoring_report_data.xlsx', sheet_name=1)
df.head(15)
# Out:
#     Row order Level of product aggregation Category or HTS number  \
# 0           1                     Category                200/301
# 1           2                     Category                200/301
# 2           3                     Category                200/301
# 3           4                     Category                200/301
# 4           5                     Category                200/301
# 5           6                     Category                200/301
# 6           7                     Category                200/301
# 7           8                     Category                200/301
# 8           9                     Category                200/301
# 9          10                     Category                200/301
# 10         11                     Category                200/301
# 11         12                     Category                200/301
# 12         13                     Category                200/301
# 13         14                     Category                200/301
# 14         15                     Category                200/301
#
#                           Category or HTS description             Source  \
# 0   Cotton & MMF yarn for retail sale and sewing t...              China
# 1   Cotton & MMF yarn for retail sale and sewing t...  All other sources
# 2   Cotton & MMF yarn for retail sale and sewing t...        All sources
# 3   Cotton & MMF yarn for retail sale and sewing t...              China
# 4   Cotton & MMF yarn for retail sale and sewing t...  All other sources
# 5   Cotton & MMF yarn for retail sale and sewing t...        All sources
# 6   Cotton & MMF yarn for retail sale and sewing t...              China
# 7   Cotton & MMF yarn for retail sale and sewing t...  All other sources
# 8   Cotton & MMF yarn for retail sale and sewing t...        All sources
# 9   Cotton & MMF yarn for retail sale and sewing t...              China
# 10  Cotton & MMF yarn for retail sale and sewing t...  All other sources
# 11  Cotton & MMF yarn for retail sale and sewing t...        All sources
# 12  Cotton & MMF yarn for retail sale and sewing t...              China
# 13  Cotton & MMF yarn for retail sale and sewing t...  All other sources
# 14  Cotton & MMF yarn for retail sale and sewing t...        All sources
#
#                            Item      Dec 2021      Nov 2021      Oct 2021  \
# 0               Value (dollars)  3.005258e+06  2.630450e+06  2.989112e+06
# 1               Value (dollars)  2.744530e+07  2.205536e+07  1.896131e+07
# 2               Value (dollars)  3.045056e+07  2.468581e+07  2.195042e+07
# 3      Share of value (percent)  9.869304e+00  1.065572e+01  1.361756e+01
# 4      Share of value (percent)  9.013070e+01  8.934428e+01  8.638244e+01
# 5      Share of value (percent)  1.000000e+02  1.000000e+02  1.000000e+02
# 6          Quantity (kilograms)  4.805470e+05  3.945740e+05  4.414630e+05
# 7          Quantity (kilograms)  4.314557e+06  3.274877e+06  2.746083e+06
# 8          Quantity (kilograms)  4.795104e+06  3.669451e+06  3.187546e+06
# 9   Share of quantity (percent)  1.002162e+01  1.075294e+01  1.384962e+01
# 10  Share of quantity (percent)  8.997838e+01  8.924706e+01  8.615038e+01
# 11  Share of quantity (percent)  1.000000e+02  1.000000e+02  1.000000e+02
# 12  Unit value ($ per kilogram)  6.253827e+00  6.666557e+00  6.770923e+00
# 13  Unit value ($ per kilogram)  6.361093e+00  6.734713e+00  6.904857e+00
# 14  Unit value ($ per kilogram)  6.350344e+00  6.727384e+00  6.886308e+00
#
#         Sep 2021  ...      Oct 2003      Sep 2003      Aug 2003      Jul 2003  \
# 0   3.480333e+06  ...  9.253110e+05  7.433190e+05  1.002834e+06  1.209634e+06
# 1   2.497756e+07  ...  2.256987e+07  2.302865e+07  2.227982e+07  2.388279e+07
# 2   2.845789e+07  ...  2.349518e+07  2.377197e+07  2.328265e+07  2.509242e+07
# 3   1.222976e+01  ...  3.938301e+00  3.126872e+00  4.307216e+00  4.820714e+00
# 4   8.777024e+01  ...  9.606170e+01  9.687313e+01  9.569278e+01  9.517929e+01
# 5   1.000000e+02  ...  1.000000e+02  1.000000e+02  1.000000e+02  1.000000e+02
# 6   4.103140e+05  ...  2.372100e+05  1.992200e+05  2.598550e+05  3.732040e+05
# 7   3.722711e+06  ...  5.607693e+06  5.523322e+06  5.729629e+06  6.218290e+06
# 8   4.133025e+06  ...  5.844903e+06  5.722542e+06  5.989484e+06  6.591494e+06
# 9   9.927692e+00  ...  4.058408e+00  3.481320e+00  4.338521e+00  5.661903e+00
# 10  9.007231e+01  ...  9.594159e+01  9.651868e+01  9.566148e+01  9.433810e+01
# 11  1.000000e+02  ...  1.000000e+02  1.000000e+02  1.000000e+02  1.000000e+02
# 12  8.482121e+00  ...  3.900809e+00  3.731146e+00  3.859206e+00  3.241214e+00
# 13  6.709508e+00  ...  4.024805e+00  4.169348e+00  3.888527e+00  3.840733e+00
# 14  6.885488e+00  ...  4.019773e+00  4.154092e+00  3.887255e+00  3.806788e+00
#
#         Jun 2003      May 2003      Apr 2003      Mar 2003      Feb 2003  \
# 0   7.203840e+05  6.632890e+05  7.344900e+05  4.665470e+05  6.273710e+05
# 1   2.440051e+07  2.415174e+07  2.274678e+07  2.237030e+07  1.889579e+07
# 2   2.512090e+07  2.481503e+07  2.348127e+07  2.283684e+07  1.952316e+07
# 3   2.867668e+00  2.672932e+00  3.127982e+00  2.042957e+00  3.213470e+00
# 4   9.713233e+01  9.732707e+01  9.687202e+01  9.795704e+01  9.678653e+01
# 5   1.000000e+02  1.000000e+02  1.000000e+02  1.000000e+02  1.000000e+02
# 6   2.093260e+05  1.606130e+05  2.153210e+05  1.476310e+05  1.499920e+05
# 7   6.021085e+06  5.815436e+06  5.430620e+06  5.102550e+06  4.526225e+06
# 8   6.230411e+06  5.976049e+06  5.645941e+06  5.250181e+06  4.676217e+06
# 9   3.359746e+00  2.687612e+00  3.813731e+00  2.811922e+00  3.207550e+00
# 10  9.664025e+01  9.731239e+01  9.618627e+01  9.718808e+01  9.679245e+01
# 11  1.000000e+02  1.000000e+02  1.000000e+02  1.000000e+02  1.000000e+02
# 12  3.441445e+00  4.129734e+00  3.411140e+00  3.160224e+00  4.182696e+00
# 13  4.052511e+00  4.153040e+00  4.188616e+00  4.384141e+00  4.174735e+00
# 14  4.031981e+00  4.152414e+00  4.158965e+00  4.349725e+00  4.174991e+00
#
#         Jan 2003
# 0   4.962010e+05
# 1   1.832541e+07
# 2   1.882161e+07
# 3   2.636337e+00
# 4   9.736366e+01
# 5   1.000000e+02
# 6   1.459310e+05
# 7   4.128683e+06
# 8   4.274614e+06
# 9   3.413899e+00
# 10  9.658610e+01
# 11  1.000000e+02
# 12  3.400244e+00
# 13  4.438560e+00
# 14  4.403113e+00
#
# [15 rows x 234 columns]

# %%
#checking the datatypes of the first six columns 
first_six=df.iloc[:,:6]
first_six.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14265 entries, 0 to 14264
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Row order                     14265 non-null  int64
#  1   Level of product aggregation  14265 non-null  object
#  2   Category or HTS number        14265 non-null  object
#  3   Category or HTS description   14265 non-null  object
#  4   Source                        14265 non-null  object
#  5   Item                          14265 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 668.8+ KB

# %%
#filtering items of interest 
categories_filter = ['5407200000','6104622011']
filt = df['Category or HTS number'].isin(categories_filter)
items_of_interest=df.loc[filt]

# %%
#filtering for the specific columns we want to see. Calling the new dataframe df2
df2=items_of_interest[(items_of_interest.Source=='China') & (items_of_interest.Item=='Value (dollars)')]

# %%
#transposing df2 into a new dataframe called df3
df3=df2.T
df3
# Out:
#                                                                             420  \
# Row order                                                                   421
# Level of product aggregation                                                HTS
# Category or HTS number                                               5407200000
# Category or HTS description   Woven Fabrics Of Synthetic Filament Yarn; Obta...
# Source                                                                    China
# ...                                                                         ...
# May 2003                                                                    0.0
# Apr 2003                                                                    0.0
# Mar 2003                                                                    0.0
# Feb 2003                                                                    0.0
# Jan 2003                                                                    0.0
#
#                                                                             990
# Row order                                                                   991
# Level of product aggregation                                                HTS
# Category or HTS number                                               6104622011
# Category or HTS description   Women'S Trousers And Breeches, Knitted Or Croc...
# Source                                                                    China
# ...                                                                         ...
# May 2003                                                               165794.0
# Apr 2003                                                               362292.0
# Mar 2003                                                               247116.0
# Feb 2003                                                               299043.0
# Jan 2003                                                               535796.0
#
# [234 rows x 2 columns]

# %%
#cleaning up the new dataframe into a time series. Deleting the first five rows in Pandas. 
df4 = df3.iloc[6:234]
df4
# Out:
#                 420         990
# Dec 2021  2511291.0  12545118.0
# Nov 2021  1975325.0  13082619.0
# Oct 2021  1815061.0  13745685.0
# Sep 2021  2218228.0  15631613.0
# Aug 2021  3069352.0  12332278.0
# ...             ...         ...
# May 2003        0.0    165794.0
# Apr 2003        0.0    362292.0
# Mar 2003        0.0    247116.0
# Feb 2003        0.0    299043.0
# Jan 2003        0.0    535796.0
#
# [228 rows x 2 columns]

# %%
#reversing the row order of the dataframe
df5 = df4.loc[::-1]
df5
# Out:
#                 420         990
# Jan 2003        0.0    535796.0
# Feb 2003        0.0    299043.0
# Mar 2003        0.0    247116.0
# Apr 2003        0.0    362292.0
# May 2003        0.0    165794.0
# ...             ...         ...
# Aug 2021  3069352.0  12332278.0
# Sep 2021  2218228.0  15631613.0
# Oct 2021  1815061.0  13745685.0
# Nov 2021  1975325.0  13082619.0
# Dec 2021  2511291.0  12545118.0
#
# [228 rows x 2 columns]

# %%
#changing the column titles 
df5.rename({420:'Value (dollars) for Woven Fabrics Of Synthetic Filament Yarn', 990:'Value (dollars) Womens Trousers And Breeches'}, 
axis=1,inplace=True)
df5
# Out:
#          Value (dollars) for Woven Fabrics Of Synthetic Filament Yarn  \
# Jan 2003                                                0.0
# Feb 2003                                                0.0
# Mar 2003                                                0.0
# Apr 2003                                                0.0
# May 2003                                                0.0
# ...                                                     ...
# Aug 2021                                          3069352.0
# Sep 2021                                          2218228.0
# Oct 2021                                          1815061.0
# Nov 2021                                          1975325.0
# Dec 2021                                          2511291.0
#
#          Value (dollars) Womens Trousers And Breeches
# Jan 2003                                     535796.0
# Feb 2003                                     299043.0
# Mar 2003                                     247116.0
# Apr 2003                                     362292.0
# May 2003                                     165794.0
# ...                                               ...
# Aug 2021                                   12332278.0
# Sep 2021                                   15631613.0
# Oct 2021                                   13745685.0
# Nov 2021                                   13082619.0
# Dec 2021                                   12545118.0
#
# [228 rows x 2 columns]

# %%
#importing matplotlib and making charts available inside the notebook
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
df5.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot: >

# %%
#creating subplots
fig2, ax2 = plt.subplots(2,1)
df5['Value (dollars) for Woven Fabrics Of Synthetic Filament Yarn'].plot(ax=ax2[0])
df5['Value (dollars) Womens Trousers And Breeches'].plot(ax=ax2[1])
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
